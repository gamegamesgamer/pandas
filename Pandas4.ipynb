# %%
import pandas as pd
import numpy as np

# %%
A=np.random.randint(0,5,20).reshape(5,4)
A
# Out:
# array([[3, 2, 2, 3],
#        [3, 0, 1, 0],
#        [4, 1, 0, 3],
#        [0, 2, 1, 1],
#        [2, 1, 3, 2]])

# %%
index=['A','B','C','D','E']

# %%
columns=['W','X','Y','Z']

# %%
B=pd.DataFrame(A,index,columns)
B
# Out:
#    W  X  Y  Z
# A  3  2  2  3
# B  3  0  1  0
# C  4  1  0  3
# D  0  2  1  1
# E  2  1  3  2

# %%
B>1
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False  False
# C   True  False  False   True
# D  False   True  False  False
# E   True  False   True   True

# %%
B[B>1]
# Out:
#      W    X    Y    Z
# A  3.0  2.0  2.0  3.0
# B  3.0  NaN  NaN  NaN
# C  4.0  NaN  NaN  3.0
# D  NaN  2.0  NaN  NaN
# E  2.0  NaN  3.0  2.0

# %%
B['W']>1
# Out:
# A     True
# B     True
# C     True
# D    False
# E     True
# Name: W, dtype: bool

# %%
B[B['W']>1]
# Out:
#    W  X  Y  Z
# A  3  2  2  3
# B  3  0  1  0
# C  4  1  0  3
# E  2  1  3  2

# %%
B[B['Z']>1]
# Out:
#    W  X  Y  Z
# A  3  2  2  3
# C  4  1  0  3
# E  2  1  3  2

# %%
B[B['Z']>1]['W']
# Out:
# A    3
# C    4
# E    2
# Name: W, dtype: int64

# %%
B[B['Z']>1]['Z']
# Out:
# A    3
# C    3
# E    2
# Name: Z, dtype: int64

# %%
B[B['Z']>1][['W','Z']]
# Out:
#    W  Z
# A  3  3
# C  4  3
# E  2  2

# %%
B[B['Z']>1][['X','Y']]
# Out:
#    X  Y
# A  2  2
# C  1  0
# E  1  3

# %%
B[(B['W']<4)&(B['Z']>1)]
# Out:
#    W  X  Y  Z
# A  3  2  2  3
# E  2  1  3  2

# %%
B[(B['W']<4)|(B['Z']>1)]
# Out:
#    W  X  Y  Z
# A  3  2  2  3
# B  3  0  1  0
# C  4  1  0  3
# D  0  2  1  1
# E  2  1  3  2
