# %%
import numpy as np
import pandas as pd

# %%
A=np.random.randint(0,10,12).reshape(3,4)
A
# Out:
# array([[8, 6, 2, 8],
#        [8, 6, 6, 3],
#        [1, 1, 9, 8]])

# %%
B=pd.DataFrame(A,['X','Y','Z'],['A','B','C','D'])
B
# Out:
#    A  B  C  D
# X  8  6  2  8
# Y  8  6  6  3
# Z  1  1  9  8

# %%
B['A']
# Out:
# X    8
# Y    8
# Z    1
# Name: A, dtype: int64

# %%
B['B']
# Out:
# X    6
# Y    6
# Z    1
# Name: B, dtype: int64

# %%
B['C']
# Out:
# X    2
# Y    6
# Z    9
# Name: C, dtype: int64

# %%
B[['A','B']]
# Out:
#    A  B
# X  8  6
# Y  8  6
# Z  1  1

# %%
B['NEW']=B['A']+B['B']
B
# Out:
#    A  B  C  D  NEW
# X  8  6  2  8   14
# Y  8  6  6  3   14
# Z  1  1  9  8    2

# %%
B.drop('NEW',axis=1)
B
# Out:
#    A  B  C  D  NEW
# X  8  6  2  8   14
# Y  8  6  6  3   14
# Z  1  1  9  8    2

# %%
B.drop('NEW',axis=1,inplace=True)
B
# Out:
#    A  B  C  D
# X  8  6  2  8
# Y  8  6  6  3
# Z  1  1  9  8

# %%
B.drop('Y',axis=0,inplace=True)
B
# Out:
#    A  B  C  D
# X  8  6  2  8
# Z  1  1  9  8

# %%
B.loc['X']
# Out:
# A    8
# B    6
# C    2
# D    8
# Name: X, dtype: int64

# %%
B.iloc[0]
# Out:
# A    8
# B    6
# C    2
# D    8
# Name: X, dtype: int64

# %%
B.loc['Z']
# Out:
# A    1
# B    1
# C    9
# D    8
# Name: Z, dtype: int64

# %%
B.iloc[1]
# Out:
# A    1
# B    1
# C    9
# D    8
# Name: Z, dtype: int64

# %%
B.loc['X','A']
# Out:
# 8

# %%
B.loc['Z','B']
# Out:
# 1

# %%
B.loc['X','C']
# Out:
# 2

# %%
B.loc[['X','Z'],['A','B']]
# Out:
#    A  B
# X  8  6
# Z  1  1

# %%
B.loc[['X','Z'],['B','D']]
# Out:
#    B  D
# X  6  8
# Z  1  8

# %%
B
# Out:
#    A  B  C  D
# X  8  6  2  8
# Z  1  1  9  8

# %%
B.reset_index()
# Out:
#   index  A  B  C  D
# 0     X  8  6  2  8
# 1     Z  1  1  9  8

# %%
B
# Out:
#    A  B  C  D
# X  8  6  2  8
# Z  1  1  9  8

# %%
B.reset_index(inplace=True)
B
# Out:
#   index  A  B  C  D
# 0     X  8  6  2  8
# 1     Z  1  1  9  8

# %%
B.set_index('index')
# Out:
#        A  B  C  D
# index
# X      8  6  2  8
# Z      1  1  9  8
