# %%
import pandas as pd
import numpy as np

# %%
A=[1,2,3,4]
A
# Out:
# [1, 2, 3, 4]

# %%
B={'a':1,'b':2,'c':3,'d':4}
B
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
C=np.array(A)
C
# Out:
# array([1, 2, 3, 4])

# %%
D=['a','b','c','d']
D
# Out:
# ['a', 'b', 'c', 'd']

# %%
pd.Series(A)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.Series(A,D)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
pd.Series(B)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
pd.Series(C)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
E=pd.Series([11,12,13,14],['India','Australia','Pakistanb','USA'])
E
# Out:
# India        11
# Australia    12
# Pakistanb    13
# USA          14
# dtype: int64

# %%
E['India']
# Out:
# 11

# %%
E['Australia']
# Out:
# 12

# %%
F=pd.Series([91,92,93,94],[1,2,3,4])
F
# Out:
# 1    91
# 2    92
# 3    93
# 4    94
# dtype: int64

# %%
F[1]
# Out:
# 91

# %%
F[2]
# Out:
# 92

# %%
F[3]
# Out:
# 93

# %%
F[4]
# Out:
# 94
